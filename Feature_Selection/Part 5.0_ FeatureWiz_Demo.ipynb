# %% [markdown]
# <a href="https://colab.research.google.com/github/gulabpatel/Feature_Selection/blob/main/Part%205.0%3A%20FeatureWiz_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/AutoViML/featurewiz.git

# %%
from featurewiz import featurewiz
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Imported featurewiz. Version = 0.1.22. nrows=None uses all rows. Set nrows=1000 to randomly sample 1000 rows.
# outputs = featurewiz(dataname, target, corr_limit=0.70, verbose=2, sep=',',
# 		header=0, test_data='',feature_engg='', category_encoders='',
# 		dask_xgboost_flag=False, nrows=None)
# Create new features via 'feature_engg' flag : ['interactions','groupby','target']

# %%
import numpy as np
import pandas as pd
dataset = pd.read_csv('https://raw.githubusercontent.com/gulabpatel/Feature_Selection/master/breast_cancer.csv')
print(dataset.shape)
dataset.head()
# Out:
# (569, 33)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
target = ['diagnosis']
features = featurewiz('https://raw.githubusercontent.com/gulabpatel/Feature_Selection/master/breast_cancer.csv', target, corr_limit=0.70,verbose=2)
# Out:
# ############################################################################################
# ############       F A S T   F E A T U R E  E N G G    A N D    S E L E C T I O N ! ########
# # Be judicious with featurewiz. Don't use it to create too many un-interpretable features! #
# ############################################################################################
# Skipping feature engineering since no feature_engg input...
# Skipping category encoding since no category encoders specified in input...
# **INFO: featurewiz can now read feather formatted files. Loading train data...
# **INFO: to increase file loading performance, convert huge `csv` files to `feather` format
# **INFO: Use `df.reset_index(drop=True).to_feather("path/to/save/file.ftr")` to save file in feather format**
#     Shape of your Data Set loaded: (569, 33)
#      Loaded. Shape = (569, 33)
#
# ...
# No test data filename given...
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# ...

# %%
print('Selected %d features:%s' %(len(features),features))
# Out:
# Selected 2 features:([],      diagnosis
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 564          1
# 565          1
# 566          1
# 567          1
# 568          0
#
# [569 rows x 1 columns])
